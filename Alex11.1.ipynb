# %% [markdown]
# <a href="https://colab.research.google.com/github/xxx0708/CNN/blob/main/Alex11.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup code

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import torch
import torchvision
import matplotlib.pyplot as plt
import statistics
import numpy as np
import torch.nn.functional as F
import torchvision.transforms as transforms
from PIL import Image
from torch.utils.data import sampler
from matplotlib.pyplot import imshow
import torch.nn as nn
import torchvision.transforms as T
from torch.utils.data import DataLoader
import torch.optim as optim
import torchvision.datasets as dset

# %%
device = torch.device('cuda'if torch.cuda.is_available()else'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# # Check Accuracy

# %%
def check_accuracy_part(loader, model):
  if loader.dataset.train:
    print('Checking accuracy on validation set')
  else:
    print('Checking accuracy on test set')   
  num_correct = 0
  num_samples = 0
  model.eval()  # set model to evaluation mode
  with torch.no_grad():
    for x, y in loader:
      x = x.to(device, dtype=torch.float)  # move to device, e.g. GPU
      y = y.to(device, dtype=torch.long)
      scores = model(x)
      _, preds = scores.max(1)
      num_correct += (preds == y).sum()
      num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
  return acc

# %% [markdown]
# # 训练模型

# %%
def train_part(model, optimizer, epochs=1, learning_rate_decay=.1, schedule=[], verbose=True):
  """
  Train a model on CIFAR-10 using the PyTorch Module API.
  
  Inputs:
  - model: A PyTorch Module giving the model to train.
  - optimizer: An Optimizer object we will use to train the model
  - epochs: (Optional) A Python integer giving the number of epochs to train for
  
  Returns: Nothing, but prints model accuracies during training.
  """
  model = model.to(device)  # move the model parameters to CPU/GPU
  num_iters = epochs * len(loader_train)
  print_every = 100
  if verbose:
    num_prints = num_iters // print_every + 1
  else:
    num_prints = epochs
  acc_history = torch.zeros(num_prints, dtype=torch.float)
  iter_history = torch.zeros(num_prints, dtype=torch.long)
  for e in range(epochs):
    
#     adjust_learning_rate(optimizer, learning_rate_decay, e, schedule)
    
    for t, (x, y) in enumerate(loader_train):
      model.train()  # put model to training mode
      x = x.to(device, dtype=torch.float)  # move to device, e.g. GPU
      y = y.to(device, dtype=torch.long)
      scores = model(x)
      loss = F.cross_entropy(scores, y)
     
      # Zero out all of the gradients for the variables which the optimizer
      # will update.
      optimizer.zero_grad()

      # This is the backwards pass: compute the gradient of the loss with
      # respect to each  parameter of the model.
      loss.backward()

      # Actually update the parameters of the model using the gradients
      # computed by the backwards pass.
      optimizer.step()

      tt = t + e * len(loader_train)

      if verbose and (tt % print_every == 0 or (e == epochs-1 and t == len(loader_train)-1)):
        print('Epoch %d, Iteration %d, loss = %.4f' % (e, tt, loss.item()))
        acc = check_accuracy_part(loader_val, model)
        acc_history[tt // print_every] = acc
        iter_history[tt // print_every] = tt
        print()
      elif not verbose and (t == len(loader_train)-1):
        print('Epoch %d, Iteration %d, loss = %.4f' % (e, tt, loss.item()))
        acc = check_accuracy_part(loader_val, model)
        acc_history[e] = acc
        iter_history[e] = tt
        print()
  return acc_history, iter_history

# %% [markdown]
# # Module API:
# conv_ReLU_conv_ReLU_conv_BN_ReLU_Pool_FC_FC

# %%
class AlexNet(nn.Module):
  def __init__(self):
     super(AlexNet,self).__init__()
     self.conv=nn.Sequential(
        #第一层
        nn.Conv2d(3,96,kernel_size=11,stride=4,padding=2),
        nn.ReLU(),
        nn.LocalResponseNorm(size=5,alpha=0.0001,beta=0.75,k=2),
        nn.MaxPool2d(3,2),
         #第二层
        nn.Conv2d(96,256,kernel_size=5,padding=2),
        nn.ReLU(),
        nn.LocalResponseNorm(size=5,alpha=0.0001,beta=0.75,k=2),
        nn.MaxPool2d(3,2),
        #第三层
        nn.Conv2d(256,384,kernel_size=3,padding=1),
        nn.ReLU(),
        #第四层
        nn.Conv2d(384,384,kernel_size=3,padding=1),
        nn.ReLU(),
        #第五层
        nn.Conv2d(384,256,kernel_size=3,padding=1),
        nn.ReLU(),
        nn.MaxPool2d(3,2),
     )
     self.fc = nn.Sequential(
       nn.Linear(256*6*6,4096),
       nn.ReLU(),
       nn.Dropout(0.5),
       nn.Linear(4096,4096),
       nn.ReLU(),
       nn.Dropout(0.5),
       nn.Linear(4096,10)
     )
     
  def forward(self,x):
    feature = self.conv(x)
    output = self.fc(feature.view(-1,256*6*6))
    return output
model = AlexNet().cuda()
print('Architecture:')
print(model) # printing `nn.Module` shows the architecture of the module.
# Out:
# Architecture:
# AlexNet(
#   (conv): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU()
#     (2): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (5): ReLU()
#     (6): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=9216, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
def load_CIFAR(path='./'):
  NUM_TRAIN = 40000
  # The torchvision.transforms package provides tools for preprocessing data
  # and for performing data augmentation; here we set up a transform to
  # preprocess the data by subtracting the mean RGB value and dividing by the
  # standard deviation of each RGB value; we've hardcoded the mean and std.
  transform = T.Compose([
                  T.ToTensor(),
                  T.Resize([224,224]),
#                   T.RandomHorizontalFlip(p=0.4),
#                   T.RandomVerticalFlip(p=0.4),
                  T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
              ])

  # We set up a Dataset object for each split (train / val / test); Datasets load
  # training examples one at a time, so we wrap each Dataset in a DataLoader which
  # iterates through the Dataset and forms minibatches. We divide the CIFAR-10
  # training set into train and val sets by passing a Sampler object to the
  # DataLoader telling how it should sample from the underlying Dataset.
  cifar10_train = dset.CIFAR10(path, train=True, download=True,
                               transform=transform)
  loader_train = DataLoader(cifar10_train, batch_size=64, 
                            sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

  cifar10_val = dset.CIFAR10(path, train=True, download=True,
                             transform=transform)
  loader_val = DataLoader(cifar10_val, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

  cifar10_test = dset.CIFAR10(path, train=False, download=True, 
                              transform=transform)
  loader_test = DataLoader(cifar10_test, batch_size=64)
  return loader_train, loader_val, loader_test
loader_train, loader_val, loader_test = load_CIFAR(path='./datasets/')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./datasets/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./datasets/cifar-10-python.tar.gz to ./datasets/
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Training Loop

# %%
# main_dir = os.getcwd()
# train_dir = main_dir + "/cifar-10to6/extract_train"
# test_dir = main_dir + "/cifar-10to6/extract_test"

epochs = 30
learning_rate = 0.01
weight_decay = 1e-4

model= AlexNet()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, 
                        weight_decay=weight_decay,
                        momentum=0.5, nesterov=True)

acc_hist_part, itr = train_part(model, optimizer,epochs=epochs)
val_acc = check_accuracy_part(loader_val, model)
test_acc = check_accuracy_part(loader_test, model)
print('\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch 0, Iteration 0, loss = 2.3028
# Checking accuracy on validation set
# Got 1003 / 10000 correct (10.03)
#
# Epoch 0, Iteration 100, loss = 2.3021
# Checking accuracy on validation set
# Got 980 / 10000 correct (9.80)
#
# Epoch 0, Iteration 200, loss = 2.3039
# Checking accuracy on validation set
# Got 1003 / 10000 correct (10.03)
#
# Epoch 0, Iteration 300, loss = 2.3029
# Checking accuracy on validation set
# Got 1003 / 10000 correct (10.03)
#
# Epoch 0, Iteration 400, loss = 2.3038
# Checking accuracy on validation set
# Got 952 / 10000 correct (9.52)
#
# Epoch 0, Iteration 500, loss = 2.3007
# Checking accuracy on validation set
# Got 1025 / 10000 correct (10.25)
#
# Epoch 0, Iteration 600, loss = 2.3024
# Checking accuracy on validation set
# Got 1304 / 10000 correct (13.04)
#
# Epoch 1, Iteration 700, loss = 2.3021
# Checking accuracy on validation set
# Got 980 / 10000 correct (9.80)
#
# Epoch 1, Iteration 800, loss = 2.3041
# Checking accuracy on validation set
# Got 980 / 10000 correct (9.80)
#
# Epoch 1, Iteration 900, loss = 2.3030
# Checking accuracy on validation set
# Got 980 / 10000 correct (9.80)
#
# Epoch 1, Iteration 1000, loss = 2.3036
# Checking accuracy on validation set
# Got 965 / 10000 correct (9.65)
#
# Epoch 1, Iteration 1100, loss = 2.3025
# Checking accuracy on validation set
# Got 1200 / 10000 correct (12.00)
#
# Epoch 1, Iteration 1200, loss = 2.3035
# Checking accuracy on validation set
# Got 954 / 10000 correct (9.54)
#
# Epoch 2, Iteration 1300, loss = 2.3035
# Checking accuracy on validation set
# Got 980 / 10000 correct (9.80)
#
# Epoch 2, Iteration 1400, loss = 2.2974
# Checking accuracy on validation set
# Got 1163 / 10000 correct (11.63)
#
# Epoch 2, Iteration 1500, loss = 2.3014
# Checking accuracy on validation set
# Got 988 / 10000 correct (9.88)
#
# Epoch 2, Iteration 1600, loss = 2.3002
# Checking accuracy on validation set
# Got 1338 / 10000 correct (13.38)
#
# Epoch 2, Iteration 1700, loss = 2.2912
# Checking accuracy on validation set
# Got 1628 / 10000 correct (16.28)
#
# Epoch 2, Iteration 1800, loss = 2.2892
# Checking accuracy on validation set
# Got 1744 / 10000 correct (17.44)
#
# Epoch 3, Iteration 1900, loss = 2.2174
# Checking accuracy on validation set
# Got 1639 / 10000 correct (16.39)
#
# Epoch 3, Iteration 2000, loss = 2.1880
# Checking accuracy on validation set
# Got 2322 / 10000 correct (23.22)
#
# Epoch 3, Iteration 2100, loss = 1.9831
# Checking accuracy on validation set
# Got 2733 / 10000 correct (27.33)
#
# Epoch 3, Iteration 2200, loss = 1.9123
# Checking accuracy on validation set
# Got 2795 / 10000 correct (27.95)
#
# Epoch 3, Iteration 2300, loss = 1.9930
# Checking accuracy on validation set
# Got 3059 / 10000 correct (30.59)
#
# Epoch 3, Iteration 2400, loss = 1.7270
# Checking accuracy on validation set
# Got 3298 / 10000 correct (32.98)
#
# Epoch 4, Iteration 2500, loss = 1.6237
# Checking accuracy on validation set
# Got 3531 / 10000 correct (35.31)
#
# Epoch 4, Iteration 2600, loss = 1.8258
# Checking accuracy on validation set
# Got 3677 / 10000 correct (36.77)
#
# Epoch 4, Iteration 2700, loss = 1.5978
# Checking accuracy on validation set
# Got 3562 / 10000 correct (35.62)
#
# Epoch 4, Iteration 2800, loss = 1.5716
# Checking accuracy on validation set
# Got 3939 / 10000 correct (39.39)
#
# Epoch 4, Iteration 2900, loss = 1.7099
# Checking accuracy on validation set
# Got 4019 / 10000 correct (40.19)
#
# Epoch 4, Iteration 3000, loss = 1.6038
# Checking accuracy on validation set
# Got 3949 / 10000 correct (39.49)
#
# Epoch 4, Iteration 3100, loss = 1.4326
# Checking accuracy on validation set
# Got 4217 / 10000 correct (42.17)
#
# Epoch 5, Iteration 3200, loss = 1.8127
# Checking accuracy on validation set
# Got 4267 / 10000 correct (42.67)
#
# Epoch 5, Iteration 3300, loss = 1.4150
# Checking accuracy on validation set
# Got 4252 / 10000 correct (42.52)
#
# Epoch 5, Iteration 3400, loss = 1.3858
# Checking accuracy on validation set
# Got 4374 / 10000 correct (43.74)
#
# Epoch 5, Iteration 3500, loss = 1.6183
# Checking accuracy on validation set
# Got 4439 / 10000 correct (44.39)
#
# Epoch 5, Iteration 3600, loss = 1.2045
# Checking accuracy on validation set
# Got 4418 / 10000 correct (44.18)
#
# Epoch 5, Iteration 3700, loss = 1.3768
# Checking accuracy on validation set
# Got 4405 / 10000 correct (44.05)
#
# Epoch 6, Iteration 3800, loss = 1.4689
# Checking accuracy on validation set
# Got 4427 / 10000 correct (44.27)
#
# Epoch 6, Iteration 3900, loss = 1.6970
# Checking accuracy on validation set
# Got 4572 / 10000 correct (45.72)
#
# Epoch 6, Iteration 4000, loss = 1.4362
# Checking accuracy on validation set
# Got 4701 / 10000 correct (47.01)
#
# Epoch 6, Iteration 4100, loss = 1.7015
# Checking accuracy on validation set
# Got 4396 / 10000 correct (43.96)
#
# Epoch 6, Iteration 4200, loss = 1.3642
# Checking accuracy on validation set
# Got 4844 / 10000 correct (48.44)
#
# Epoch 6, Iteration 4300, loss = 1.5589
# Checking accuracy on validation set
# Got 4885 / 10000 correct (48.85)
#
# Epoch 7, Iteration 4400, loss = 1.4335
# Checking accuracy on validation set
# Got 5136 / 10000 correct (51.36)
#
# Epoch 7, Iteration 4500, loss = 1.2623
# Checking accuracy on validation set
# Got 5041 / 10000 correct (50.41)
#
# Epoch 7, Iteration 4600, loss = 1.3680
# Checking accuracy on validation set
# Got 4950 / 10000 correct (49.50)
#
# Epoch 7, Iteration 4700, loss = 1.3057
# Checking accuracy on validation set
# Got 5280 / 10000 correct (52.80)
#
# Epoch 7, Iteration 4800, loss = 1.3666
# Checking accuracy on validation set
# Got 5170 / 10000 correct (51.70)
#
# Epoch 7, Iteration 4900, loss = 1.5426
# Checking accuracy on validation set
# Got 5232 / 10000 correct (52.32)
#
# Epoch 8, Iteration 5000, loss = 1.4456
# Checking accuracy on validation set
# Got 5394 / 10000 correct (53.94)
#
# Epoch 8, Iteration 5100, loss = 1.3275
# Checking accuracy on validation set
# Got 5176 / 10000 correct (51.76)
#
# Epoch 8, Iteration 5200, loss = 1.3246
# Checking accuracy on validation set
# Got 5442 / 10000 correct (54.42)
#
# Epoch 8, Iteration 5300, loss = 1.1890
# Checking accuracy on validation set
# Got 5549 / 10000 correct (55.49)
#
# Epoch 8, Iteration 5400, loss = 1.1795
# Checking accuracy on validation set
# Got 5658 / 10000 correct (56.58)
#
# Epoch 8, Iteration 5500, loss = 1.3504
# Checking accuracy on validation set
# Got 5609 / 10000 correct (56.09)
#
# Epoch 8, Iteration 5600, loss = 1.1682
# Checking accuracy on validation set
# Got 5560 / 10000 correct (55.60)
#
# Epoch 9, Iteration 5700, loss = 1.1781
# Checking accuracy on validation set
# Got 5465 / 10000 correct (54.65)
#
# Epoch 9, Iteration 5800, loss = 1.2265
# Checking accuracy on validation set
# Got 5714 / 10000 correct (57.14)
#
# Epoch 9, Iteration 5900, loss = 1.2575
# Checking accuracy on validation set
# Got 5827 / 10000 correct (58.27)
#
# Epoch 9, Iteration 6000, loss = 1.2613
# Checking accuracy on validation set
# Got 5634 / 10000 correct (56.34)
#
# Epoch 9, Iteration 6100, loss = 1.1775
# Checking accuracy on validation set
# Got 5810 / 10000 correct (58.10)
#
# Epoch 9, Iteration 6200, loss = 1.5900
# Checking accuracy on validation set
# Got 5580 / 10000 correct (55.80)
#
# Epoch 10, Iteration 6300, loss = 1.1418
# Checking accuracy on validation set
# Got 5934 / 10000 correct (59.34)
#
# Epoch 10, Iteration 6400, loss = 1.1090
# Checking accuracy on validation set
# Got 6042 / 10000 correct (60.42)
#
# Epoch 10, Iteration 6500, loss = 1.1009
# Checking accuracy on validation set
# Got 6110 / 10000 correct (61.10)
#
# Epoch 10, Iteration 6600, loss = 1.1788
# Checking accuracy on validation set
# Got 6138 / 10000 correct (61.38)
#
# Epoch 10, Iteration 6700, loss = 1.2192
# Checking accuracy on validation set
# Got 5894 / 10000 correct (58.94)
#
# Epoch 10, Iteration 6800, loss = 0.9857
# Checking accuracy on validation set
# Got 6232 / 10000 correct (62.32)
#
# Epoch 11, Iteration 6900, loss = 1.4168
# Checking accuracy on validation set
# Got 6028 / 10000 correct (60.28)
#
# Epoch 11, Iteration 7000, loss = 1.0479
# Checking accuracy on validation set
# Got 6348 / 10000 correct (63.48)
#
# Epoch 11, Iteration 7100, loss = 1.0808
# Checking accuracy on validation set
# Got 6326 / 10000 correct (63.26)
#
# Epoch 11, Iteration 7200, loss = 0.8655
# Checking accuracy on validation set
# Got 6402 / 10000 correct (64.02)
#
# Epoch 11, Iteration 7300, loss = 1.0351
# Checking accuracy on validation set
# Got 6328 / 10000 correct (63.28)
#
# Epoch 11, Iteration 7400, loss = 1.2112
# Checking accuracy on validation set
# Got 6401 / 10000 correct (64.01)
#
# Epoch 12, Iteration 7500, loss = 1.1057
# Checking accuracy on validation set
# Got 6353 / 10000 correct (63.53)
#
# Epoch 12, Iteration 7600, loss = 0.9296
# Checking accuracy on validation set
# Got 6286 / 10000 correct (62.86)
#
# Epoch 12, Iteration 7700, loss = 0.8740
# Checking accuracy on validation set
# Got 6462 / 10000 correct (64.62)
#
# Epoch 12, Iteration 7800, loss = 0.8733
# Checking accuracy on validation set
# Got 6707 / 10000 correct (67.07)
#
# Epoch 12, Iteration 7900, loss = 0.9018
# Checking accuracy on validation set
# Got 6389 / 10000 correct (63.89)
#
# Epoch 12, Iteration 8000, loss = 0.8840
# Checking accuracy on validation set
# Got 6823 / 10000 correct (68.23)
#
# Epoch 12, Iteration 8100, loss = 1.1858
# Checking accuracy on validation set
# Got 6766 / 10000 correct (67.66)
#
# Epoch 13, Iteration 8200, loss = 1.0274
# Checking accuracy on validation set
# Got 6726 / 10000 correct (67.26)
#
# Epoch 13, Iteration 8300, loss = 0.8712
# Checking accuracy on validation set
# Got 6867 / 10000 correct (68.67)
#
# Epoch 13, Iteration 8400, loss = 0.9328
# Checking accuracy on validation set
# Got 6677 / 10000 correct (66.77)
#
# Epoch 13, Iteration 8500, loss = 1.0495
# Checking accuracy on validation set
# Got 6879 / 10000 correct (68.79)
#
# Epoch 13, Iteration 8600, loss = 1.0625
# Checking accuracy on validation set
# Got 6766 / 10000 correct (67.66)
#
# Epoch 13, Iteration 8700, loss = 0.7468
# Checking accuracy on validation set
# Got 6906 / 10000 correct (69.06)
#
# Epoch 14, Iteration 8800, loss = 0.8530
# Checking accuracy on validation set
# Got 6710 / 10000 correct (67.10)
#
# Epoch 14, Iteration 8900, loss = 1.0109
# Checking accuracy on validation set
# Got 7043 / 10000 correct (70.43)
#
# Epoch 14, Iteration 9000, loss = 0.8673
# Checking accuracy on validation set
# Got 7163 / 10000 correct (71.63)
#
# Epoch 14, Iteration 9100, loss = 0.4894
# Checking accuracy on validation set
# Got 6982 / 10000 correct (69.82)
#
# Epoch 14, Iteration 9200, loss = 0.8037
# Checking accuracy on validation set
# Got 7075 / 10000 correct (70.75)
#
# Epoch 14, Iteration 9300, loss = 0.7817
# Checking accuracy on validation set
# Got 7235 / 10000 correct (72.35)
#
# Epoch 15, Iteration 9400, loss = 0.7843
# Checking accuracy on validation set
# Got 7183 / 10000 correct (71.83)
#
# Epoch 15, Iteration 9500, loss = 0.6508
# Checking accuracy on validation set
# Got 7130 / 10000 correct (71.30)
#
# Epoch 15, Iteration 9600, loss = 0.7687
# Checking accuracy on validation set
# Got 7187 / 10000 correct (71.87)
#
# Epoch 15, Iteration 9700, loss = 0.8659
# Checking accuracy on validation set
# Got 7157 / 10000 correct (71.57)
#
# Epoch 15, Iteration 9800, loss = 0.7861
# Checking accuracy on validation set
# Got 7338 / 10000 correct (73.38)
#
# Epoch 15, Iteration 9900, loss = 0.5962
# Checking accuracy on validation set
# Got 7133 / 10000 correct (71.33)
#
# Epoch 16, Iteration 10000, loss = 0.5302
# Checking accuracy on validation set
# Got 7459 / 10000 correct (74.59)
#
# Epoch 16, Iteration 10100, loss = 0.9432
# Checking accuracy on validation set
# Got 7321 / 10000 correct (73.21)
#
# Epoch 16, Iteration 10200, loss = 0.8110
# Checking accuracy on validation set
# Got 7202 / 10000 correct (72.02)
#
# Epoch 16, Iteration 10300, loss = 0.8998
# Checking accuracy on validation set
# Got 7373 / 10000 correct (73.73)
#
# Epoch 16, Iteration 10400, loss = 0.6339
# Checking accuracy on validation set
# Got 7396 / 10000 correct (73.96)
#
# Epoch 16, Iteration 10500, loss = 0.6637
# Checking accuracy on validation set
# Got 7436 / 10000 correct (74.36)
#
# Epoch 16, Iteration 10600, loss = 0.5669
# Checking accuracy on validation set
# Got 7455 / 10000 correct (74.55)
#
# Epoch 17, Iteration 10700, loss = 0.5559
# Checking accuracy on validation set
# Got 7391 / 10000 correct (73.91)
#
# Epoch 17, Iteration 10800, loss = 0.6086
# Checking accuracy on validation set
# Got 7494 / 10000 correct (74.94)
#
# Epoch 17, Iteration 10900, loss = 0.5094
# Checking accuracy on validation set
# Got 7487 / 10000 correct (74.87)
#
# Epoch 17, Iteration 11000, loss = 0.5457
# Checking accuracy on validation set
# Got 7502 / 10000 correct (75.02)
#
# Epoch 17, Iteration 11100, loss = 0.6804
# Checking accuracy on validation set
# Got 7519 / 10000 correct (75.19)
#
# Epoch 17, Iteration 11200, loss = 0.4632
# Checking accuracy on validation set
# Got 7605 / 10000 correct (76.05)
#
# Epoch 18, Iteration 11300, loss = 0.7976
# Checking accuracy on validation set
# Got 7490 / 10000 correct (74.90)
#
# Epoch 18, Iteration 11400, loss = 0.4754
# Checking accuracy on validation set
# Got 7469 / 10000 correct (74.69)
#
# Epoch 18, Iteration 11500, loss = 0.6213
# Checking accuracy on validation set
# Got 7564 / 10000 correct (75.64)
#
# Epoch 18, Iteration 11600, loss = 0.6352
# Checking accuracy on validation set
# Got 7451 / 10000 correct (74.51)
#
# Epoch 18, Iteration 11700, loss = 0.8175
# Checking accuracy on validation set
# Got 7683 / 10000 correct (76.83)
#
# Epoch 18, Iteration 11800, loss = 0.5363
# Checking accuracy on validation set
# Got 7594 / 10000 correct (75.94)
#
# Epoch 19, Iteration 11900, loss = 0.6486
# Checking accuracy on validation set
# Got 7657 / 10000 correct (76.57)
#
# Epoch 19, Iteration 12000, loss = 0.6556
# Checking accuracy on validation set
# Got 7696 / 10000 correct (76.96)
#
# Epoch 19, Iteration 12100, loss = 0.6582
# Checking accuracy on validation set
# Got 7686 / 10000 correct (76.86)
#
# Epoch 19, Iteration 12200, loss = 0.4348
# Checking accuracy on validation set
# Got 7727 / 10000 correct (77.27)
#
# Epoch 19, Iteration 12300, loss = 0.7392
# Checking accuracy on validation set
# Got 7576 / 10000 correct (75.76)
#
# Epoch 19, Iteration 12400, loss = 0.6280
# Checking accuracy on validation set
# Got 7681 / 10000 correct (76.81)
#
# Epoch 20, Iteration 12500, loss = 0.5066
# Checking accuracy on validation set
# Got 7589 / 10000 correct (75.89)
#
# Epoch 20, Iteration 12600, loss = 0.4667
# Checking accuracy on validation set
# Got 7770 / 10000 correct (77.70)
#
# Epoch 20, Iteration 12700, loss = 0.5165
# Checking accuracy on validation set
# Got 7707 / 10000 correct (77.07)
#
# Epoch 20, Iteration 12800, loss = 0.5822
# Checking accuracy on validation set
# Got 7660 / 10000 correct (76.60)
#
# Epoch 20, Iteration 12900, loss = 0.3229
# Checking accuracy on validation set
# Got 7814 / 10000 correct (78.14)
#
# Epoch 20, Iteration 13000, loss = 0.4963
# Checking accuracy on validation set
# Got 7840 / 10000 correct (78.40)
#
# Epoch 20, Iteration 13100, loss = 0.3995
# Checking accuracy on validation set
# Got 7737 / 10000 correct (77.37)
#
# Epoch 21, Iteration 13200, loss = 0.6202
# Checking accuracy on validation set
# Got 7924 / 10000 correct (79.24)
#
# Epoch 21, Iteration 13300, loss = 0.3903
# Checking accuracy on validation set
# Got 7815 / 10000 correct (78.15)
#
# Epoch 21, Iteration 13400, loss = 0.4559
# Checking accuracy on validation set
# Got 7844 / 10000 correct (78.44)
#
# Epoch 21, Iteration 13500, loss = 0.4110
# Checking accuracy on validation set
# Got 7746 / 10000 correct (77.46)
#
# Epoch 21, Iteration 13600, loss = 0.2700
# Checking accuracy on validation set
# Got 7820 / 10000 correct (78.20)
#
# Epoch 21, Iteration 13700, loss = 0.4689
# Checking accuracy on validation set
# Got 7911 / 10000 correct (79.11)
#
# Epoch 22, Iteration 13800, loss = 0.4140
# Checking accuracy on validation set
# Got 7819 / 10000 correct (78.19)
#
# Epoch 22, Iteration 13900, loss = 0.5436
# Checking accuracy on validation set
# Got 7644 / 10000 correct (76.44)
#
# Epoch 22, Iteration 14000, loss = 0.3383
# Checking accuracy on validation set
# Got 7900 / 10000 correct (79.00)
#
# Epoch 22, Iteration 14100, loss = 0.4706
# Checking accuracy on validation set
# Got 7973 / 10000 correct (79.73)
#
# Epoch 22, Iteration 14200, loss = 0.5100
# Checking accuracy on validation set
# Got 7831 / 10000 correct (78.31)
#
# Epoch 22, Iteration 14300, loss = 0.5172
# Checking accuracy on validation set
# Got 7986 / 10000 correct (79.86)
#
# Epoch 23, Iteration 14400, loss = 0.4602
# Checking accuracy on validation set
# Got 7938 / 10000 correct (79.38)
#
# Epoch 23, Iteration 14500, loss = 0.2620
# Checking accuracy on validation set
# Got 7866 / 10000 correct (78.66)
#
# Epoch 23, Iteration 14600, loss = 0.3146
# Checking accuracy on validation set
# Got 7838 / 10000 correct (78.38)
#
# Epoch 23, Iteration 14700, loss = 0.5085
# Checking accuracy on validation set
# Got 7858 / 10000 correct (78.58)
#
# Epoch 23, Iteration 14800, loss = 0.4500
# Checking accuracy on validation set
# Got 7943 / 10000 correct (79.43)
#
# Epoch 23, Iteration 14900, loss = 0.5029
# Checking accuracy on validation set
# Got 7944 / 10000 correct (79.44)
#
# Epoch 24, Iteration 15000, loss = 0.1542
# Checking accuracy on validation set
# Got 7875 / 10000 correct (78.75)
#
# Epoch 24, Iteration 15100, loss = 0.3202
# Checking accuracy on validation set
# Got 7930 / 10000 correct (79.30)
#
# Epoch 24, Iteration 15200, loss = 0.3619
# Checking accuracy on validation set
# Got 7984 / 10000 correct (79.84)
#
# Epoch 24, Iteration 15300, loss = 0.7339
# Checking accuracy on validation set
# Got 7763 / 10000 correct (77.63)
#
# Epoch 24, Iteration 15400, loss = 0.4879
# Checking accuracy on validation set
# Got 7821 / 10000 correct (78.21)
#
# Epoch 24, Iteration 15500, loss = 0.3988
# Checking accuracy on validation set
# Got 7902 / 10000 correct (79.02)
#
# Epoch 24, Iteration 15600, loss = 0.4288
# Checking accuracy on validation set
# Got 8013 / 10000 correct (80.13)
#
# Epoch 25, Iteration 15700, loss = 0.1557
# Checking accuracy on validation set
# Got 8001 / 10000 correct (80.01)
#
# Epoch 25, Iteration 15800, loss = 0.2530
# Checking accuracy on validation set
# Got 8068 / 10000 correct (80.68)
#
# Epoch 25, Iteration 15900, loss = 0.2587
# Checking accuracy on validation set
# Got 7987 / 10000 correct (79.87)
#
# Epoch 25, Iteration 16000, loss = 0.4546
# Checking accuracy on validation set
# Got 7762 / 10000 correct (77.62)
#
# Epoch 25, Iteration 16100, loss = 0.3652
# Checking accuracy on validation set
# Got 7998 / 10000 correct (79.98)
#
# Epoch 25, Iteration 16200, loss = 0.1825
# Checking accuracy on validation set
# Got 7861 / 10000 correct (78.61)
#
# Epoch 26, Iteration 16300, loss = 0.2150
# Checking accuracy on validation set
# Got 7990 / 10000 correct (79.90)
#
# Epoch 26, Iteration 16400, loss = 0.2633
# Checking accuracy on validation set
# Got 8011 / 10000 correct (80.11)
#
# Epoch 26, Iteration 16500, loss = 0.3180
# Checking accuracy on validation set
# Got 7932 / 10000 correct (79.32)
#
# Epoch 26, Iteration 16600, loss = 0.2525
# Checking accuracy on validation set
# Got 8078 / 10000 correct (80.78)
#
# Epoch 26, Iteration 16700, loss = 0.2538
# Checking accuracy on validation set
# Got 8046 / 10000 correct (80.46)
#
# Epoch 26, Iteration 16800, loss = 0.2071
# Checking accuracy on validation set
# Got 7939 / 10000 correct (79.39)
#
# Epoch 27, Iteration 16900, loss = 0.1531
# Checking accuracy on validation set
# Got 8053 / 10000 correct (80.53)
#
# Epoch 27, Iteration 17000, loss = 0.1617
# Checking accuracy on validation set
# Got 8033 / 10000 correct (80.33)
#
# Epoch 27, Iteration 17100, loss = 0.3493
# Checking accuracy on validation set
# Got 7931 / 10000 correct (79.31)
#
# Epoch 27, Iteration 17200, loss = 0.2904
# Checking accuracy on validation set
# Got 7987 / 10000 correct (79.87)
#
# Epoch 27, Iteration 17300, loss = 0.2032
# Checking accuracy on validation set
# Got 7998 / 10000 correct (79.98)
#
# Epoch 27, Iteration 17400, loss = 0.1990
# Checking accuracy on validation set
# Got 7992 / 10000 correct (79.92)
#
# Epoch 28, Iteration 17500, loss = 0.2576
# Checking accuracy on validation set
# Got 8005 / 10000 correct (80.05)
#
# Epoch 28, Iteration 17600, loss = 0.0900
# Checking accuracy on validation set
# Got 8061 / 10000 correct (80.61)
#
# Epoch 28, Iteration 17700, loss = 0.2089
# Checking accuracy on validation set
# Got 8105 / 10000 correct (81.05)
#
# Epoch 28, Iteration 17800, loss = 0.0846
# Checking accuracy on validation set
# Got 8089 / 10000 correct (80.89)
#
# Epoch 28, Iteration 17900, loss = 0.1879
# Checking accuracy on validation set
# Got 8079 / 10000 correct (80.79)
#
# Epoch 28, Iteration 18000, loss = 0.1497
# Checking accuracy on validation set
# Got 7964 / 10000 correct (79.64)
#
# Epoch 28, Iteration 18100, loss = 0.2950
# Checking accuracy on validation set
# Got 8067 / 10000 correct (80.67)
#
# Epoch 29, Iteration 18200, loss = 0.1371
# Checking accuracy on validation set
# Got 8074 / 10000 correct (80.74)
#
# Epoch 29, Iteration 18300, loss = 0.1134
# Checking accuracy on validation set
# Got 8081 / 10000 correct (80.81)
#
# Epoch 29, Iteration 18400, loss = 0.1791
# Checking accuracy on validation set
# Got 8118 / 10000 correct (81.18)
#
# Epoch 29, Iteration 18500, loss = 0.1040
# Checking accuracy on validation set
# Got 8064 / 10000 correct (80.64)
#
# Epoch 29, Iteration 18600, loss = 0.0905
# Checking accuracy on validation set
# Got 8061 / 10000 correct (80.61)
#
# Epoch 29, Iteration 18700, loss = 0.0915
# Checking accuracy on validation set
# Got 8000 / 10000 correct (80.00)
#
# Epoch 29, Iteration 18749, loss = 0.1718
# Checking accuracy on validation set
# Got 8103 / 10000 correct (81.03)
#
# Checking accuracy on validation set
# Got 8103 / 10000 correct (81.03)
# Checking accuracy on test set
# Got 8099 / 10000 correct (80.99)

# %%
plt.title('train accuracies')
plt.plot(itr, acc_hist_part, '-o')
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.gcf().set_size_inches(9, 4)
plt.show()
